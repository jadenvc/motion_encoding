# %%
import sys
sys.path.append('..')
from src.dataset.motion_dataset import MotionForecastingDataset
from torch.utils.data import DataLoader

# %%
train_dataset = MotionForecastingDataset('/home/dataset/train')
val_dataset = MotionForecastingDataset('/home/dataset/val')
test_dataset = MotionForecastingDataset('/home/dataset/test')

# %%
len(train_dataset)
# Out:
# 199908

# %%
train_dataset[10]
# Out:
# ArgoverseScenario(scenario_id='000410c1-84d8-43a6-b6e8-34616cc1543f', timestamps_ns=array([3.15969072e+17, 3.15969072e+17, 3.15969072e+17, 3.15969073e+17,
#        3.15969073e+17, 3.15969073e+17, 3.15969073e+17, 3.15969073e+17,
#        3.15969073e+17, 3.15969073e+17, 3.15969073e+17, 3.15969073e+17,
#        3.15969073e+17, 3.15969074e+17, 3.15969074e+17, 3.15969074e+17,
#        3.15969074e+17, 3.15969074e+17, 3.15969074e+17, 3.15969074e+17,
#        3.15969074e+17, 3.15969074e+17, 3.15969074e+17, 3.15969075e+17,
#        3.15969075e+17, 3.15969075e+17, 3.15969075e+17, 3.15969075e+17,
#        3.15969075e+17, 3.15969075e+17, 3.15969075e+17, 3.15969075e+17,
#        3.15969075e+17, 3.15969076e+17, 3.15969076e+17, 3.15969076e+17,
#        3.15969076e+17, 3.15969076e+17, 3.15969076e+17, 3.15969076e+17,
#        3.15969076e+17, 3.15969076e+17, 3.15969076e+17, 3.15969077e+17,
#        3.15969077e+17, 3.15969077e+17, 3.15969077e+17, 3.15969077e+17,
# ...

# %%
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=True)

# %%
scenarios = next(iter(train_dataloader))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 scenarios = next(iter(train_dataloader))
#
# File ~/anaconda3/envs/cs229/lib/python3.10/site-packages/torch/utils/data/dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/cs229/lib/python3.10/site-packages/torch/utils/data/dataloader.py:721, in _SingleProcessDataLoaderIter._next_data(self)
#     719 def _next_data(self):
# ...
